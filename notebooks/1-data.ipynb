# %%
import pandas as pd

# %%
df_mcq = pd.read_csv("../data/train_dataset_mcq.csv", dtype={"choices": object})
df_mcq
# Out:
#              MCQID           ID country  \
# 0     New-as-80_30    New-as-80   China
# 1     Na-ko-42_288     Na-ko-42    Iran
# 2      New-en-01_6    New-en-01      US
# 3     Al-en-34_483     Al-en-34    Iran
# 4       Na-ko-30_0     Na-ko-30      US
# ..             ...          ...     ...
# 831     Th-en-15_0     Th-en-15      UK
# 832    Th-en-51_10     Th-en-51      US
# 833   Jo-sp-19_792     Jo-sp-19   China
# 834  New-spme-60_3  New-spme-60      US
# 835     Jo-sp-02_0     Jo-sp-02      US
#
#                                                 prompt  \
# 0    What type of clothing do people from China wea...
# 1    What type of food is commonly provided at fune...
# 2    Which snack is eaten in the cinema in the US? ...
# 3    What do people do to celebrate New Year's Day ...
# 4    What is the most popular e-sports game in the ...
# ..                                                 ...
# 831  What is the most popular winter sport in the U...
# 832  Which subject is considered the most important...
# 833  What region in China has been traditionally as...
# 834  Which day of the week do most families in the ...
# 835  What is the most popular sport played without ...
#
#                                                choices  \
# 0    {\n    "A": "as usual",\n    "B": "hanbok",\n ...
# 1    {\n    "A": "coffee",\n    "B": "kebab",\n    ...
# 2    {\n    "A": "chips",\n    "B": "hummus",\n    ...
# 3    {\n    "A": "eat grapes at 12",\n    "B": "new...
# 4    {\n    "A": "LoL",\n    "B": "honor of kings",...
# ..                                                 ...
# 831  {\n    "A": "hockey",\n    "B": "rugby",\n    ...
# 832  {\n    "A": "culinary arts",\n    "B": "englis...
# 833  {\n    "A": "amhara",\n    "B": "henan",\n    ...
# 834  {\n    "A": "Sunday",\n    "B": "friday",\n   ...
# 835  {\n    "A": "archery",\n    "B": "badminton",\...
#
#                                       choice_countries answer_idx
# 0    {\n    "A": "China",\n    "B": "South_Korea",\...          A
# 1    {\n    "A": "Mexico",\n    "B": "Iran",\n    "...          B
# 2    {\n    "A": "Algeria",\n    "B": "dummy",\n   ...          D
# 3    {\n    "A": "Spain",\n    "B": "North_Korea",\...          D
# 4    {\n    "A": "US",\n    "B": "China",\n    "C":...          A
# ..                                                 ...        ...
# 831  {\n    "A": "US",\n    "B": "UK",\n    "C": "E...          B
# 832  {\n    "A": "dummy",\n    "B": "US",\n    "C":...          B
# 833  {\n    "A": "Ethiopia",\n    "B": "China",\n  ...          B
# 834  {\n    "A": "US",\n    "B": "Indonesia",\n    ...          A
# 835  {\n    "A": "South_Korea",\n    "B": "Indonesi...          C
#
# [836 rows x 7 columns]

# %%
df_mcq["prompt"][0]
# Out:
# 'What type of clothing do people from China wear during traditional festivals? Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C). Provide as JSON format: {"answer_choice":""}\n\nA. as usual\nB. hanbok\nC. kebaya\nD. sador mekhela\n\nAnswer:'

# %%
import json

keys_len = set()

for i in range(len(df_mcq)):
    choices = json.loads(df_mcq["choices"][i])
    keys = list(choices.keys())
    keys_len.add(len(keys))

# %%
keys_len
# Out:
# {4}

# %%
json.loads(df_mcq["choice_countries"][0])
# Out:
# {'A': 'China', 'B': 'South_Korea', 'C': 'Indonesia', 'D': 'Assam'}

# %%
pd.read_csv("../data/train_dataset_saq.csv")
# Out:
#              ID                                           question  \
# 0      Na-ko-25  درایران ورزش‌های معمولی که در روز ورزش مدارس ا...
# 1     New-en-79  Which region of the UK is well known for its t...
# 2      Al-en-16  At what age do kids start nursery in the UK? (...
# 3     New-as-89  What traditional festival accessories do peopl...
# 4      Gu-ch-32  در کشور شما مدت زمان آموزش اجباری به سال چقدر ...
# ...         ...                                                ...
# 1328   Ki-pe-32                                 在中国，主人通常为客人准备什么食物？
# 1329  New-ch-79                                在中国，退休男性通常喜欢什么休闲活动？
# 1330  New-ko-01  What is the most popular children's animation ...
# 1331   Ta-pe-13              在你父母那一代，中国家庭平均有多少成员？（只提供阿拉伯数字，例如：20。）
# 1332  Jod-ch-62                                     在中国，男性最偏爱哪种职业？
#
#                                             en_question  \
# 0     What are the typical sports played in Iran's s...
# 1     Which region of UK is well known for its theat...
# 2     At what age do kids start preschool in UK? (Pr...
# 3     What traditional festival accessories do peopl...
# 4     What is the duration of compulsory education i...
# ...                                                 ...
# 1328  What food do the hosts usually prepare for the...
# 1329  What leisure activities do retired men typical...
# 1330  What is the most popular children's animation ...
# 1331  In your parents' generation, what was the aver...
# 1332  Which occupation is most preferred among males...
#
#                                             annotations  \
# 0     [{'answers': ['فوتبال'], 'en_answers': ['footb...
# 1     [{'answers': ['london'], 'en_answers': ['londo...
# 2     [{'answers': ['3'], 'en_answers': ['3'], 'coun...
# 3     [{'answers': ['fourth of july clothes'], 'en_a...
# 4     [{'answers': ['8'], 'en_answers': ['8'], 'coun...
# ...                                                 ...
# 1328  [{'answers': ['热炒'], 'en_answers': ['stir-fry'...
# 1329  [{'answers': ['下象棋', '下棋'], 'en_answers': ['pl...
# 1330  [{'answers': ['spongebob'], 'en_answers': ['sp...
# 1331  [{'answers': ['5'], 'en_answers': ['5'], 'coun...
# 1332  [{'answers': ['公务员'], 'en_answers': ['civil se...
#
#                                                  idks country
# 0     {'idk': 0, 'no-answer': 0, 'not-applicable': 0}      IR
# 1     {'idk': 0, 'no-answer': 0, 'not-applicable': 0}      GB
# 2     {'idk': 0, 'no-answer': 0, 'not-applicable': 0}      GB
# 3     {'no-answer': 2, 'not-applicable': 2, 'idk': 1}      US
# 4     {'no-answer': 1, 'idk': 1, 'not-applicable': 0}      IR
# ...                                               ...     ...
# 1328  {'no-answer': 1, 'idk': 0, 'not-applicable': 0}      CN
# 1329  {'idk': 0, 'no-answer': 0, 'not-applicable': 0}      CN
# 1330  {'idk': 1, 'no-answer': 1, 'not-applicable': 0}      US
# 1331  {'idk': 0, 'no-answer': 0, 'not-applicable': 0}      CN
# 1332  {'idk': 1, 'no-answer': 1, 'not-applicable': 0}      CN
#
# [1333 rows x 6 columns]
